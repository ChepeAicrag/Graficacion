# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('classic')

def drawPoint(x, y):
  print(f'({x}, {y})')
  plt.scatter(x, y)

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 20 #Número de filas y columnas de la matriz (cuadrada)
matriz_linea = np.zeros((N,N))#creamos la matriz con ceros en todas las celdas
matriz_circunferencia = np.zeros((N,N))#creamos la matriz con ceros en todas las celdas
linea = [] #Lista en donde se insertarán las coordenadas de los pixeles a pintar con la siguiente forma [x,y] para la línea

# %%
def imprimir_linea():
  for c in linea:
    matriz_linea[c[0],c[1]] = 1
    
  plt.imshow(matriz_linea)
  plt.colorbar()
  plt.show()

# %%
def DDA(p1, p2): 
  x0, y0 = p1
  x1, y1 = p2
  x, y = x0, y0
  dx, dy = x1 - x0, y1 - y0  
  m = dy / dx if dx != 0 else 0
  pasos = abs(dy) if abs(dy) > abs(dx) else abs(dx)
  x_inc = dx / pasos if pasos != 0 else 0
  y_inc = dy / pasos if pasos != 0 else 1
  drawPoint(x, y)
  #linea.append([round(y), round(x)])
  if (x0 < 0 and x1 < 0):
    x_inc = x_inc + 0.1
  elif (x0 < 0 and x1 > 0):
    x_inc = x_inc - 0.1
  for _ in range(pasos): 
    x, y = x + x_inc, y + y_inc
    #linea.append([round(y), round(x)])
    drawPoint(round(x), round(y))
  #imprimir_linea()#Este es el llamado a la función que se encarga de plotear la matriz

# Test de derecha izquierda 

#DDA((1,1), (4, 4))
#DDA((4, 4), (1, 1))

#DDA((1,1), (4, 1))
#DDA((4, 1), (1, 1))

#DDA((1, 1), (1, 4))
#DDA((1, 4), (1, 1))

#DDA((1, 4), (4, 1))
#DDA((4, 1), (1, 4))


#DDA((2,3), (3,1))
#DDA((3, 1), (2, 3))

#DDA((-1, 1), (-2, -1))
#DDA((-2, -1), (-1, 1))

DDA((3, 10), (1, 4))
# Out:
# (3, 10)
# (3, 9)
# (2, 8)
# (2, 7)
# (2, 6)
# (1, 5)
# (1, 4)
